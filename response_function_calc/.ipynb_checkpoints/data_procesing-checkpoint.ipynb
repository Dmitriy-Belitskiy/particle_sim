# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot
from concurrent.futures import ThreadPoolExecutor
import os
import glob
import re
from tqdm import tqdm
import imageio
import open3d as o3d
from scipy.ndimage import gaussian_filter

import matplotlib.animation as animation
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
files=glob.glob("./build/dump/data_root/*root")

sorted_files = sorted(files, key=lambda x: int(re.search(r'\d+', x).group()))

#sorted_files = sorted(files, key=lambda x: int(re.search(r'\d+', x).group()))

# %%
# for i,item in enumerate(sorted_files):
#     print(i,item)

# sorted_files=[sorted_files[5]]

# print(sorted_files)
# Out:
# 0 ./build/dump/data_root/output0_m10.root
# 1 ./build/dump/data_root/output_wg0.root
# 2 ./build/dump/data_root/output0_m100.root
# 3 ./build/dump/data_root/output0.root
# 4 ./build/dump/data_root/output_real_det_grnd_0.root
# 5 ./build/dump/data_root/1b_bcg0.root
# 6 ./build/dump/data_root/output_f1.root
# 7 ./build/dump/data_root/output1_0.root
# 8 ./build/dump/data_root/output9.root
# 9 ./build/dump/data_root/output10.root
# 10 ./build/dump/data_root/output_g_100m_0.root
# ['./build/dump/data_root/1b_bcg0.root']

# %%
dump=[]
labels=[]


for file in sorted_files:
    labels.append(file)
    workers=8

    decompression_executor = ThreadPoolExecutor(max_workers=workers)
    interpretation_executor = ThreadPoolExecutor(max_workers=workers)


    with uproot.open(file,num_workers=workers,
                     decompression_executor=decompression_executor,
                     interpretation_executor=interpretation_executor) as file:
        print('start_loading')
        tree = file['B4;1']
        braunches=['Edep']
        data=tree.arrays( braunches,library="np")

        # Clean up executors
    decompression_executor.shutdown()
    interpretation_executor.shutdown()

    dump.append(data)
# Out:
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading
# start_loading

# %%
# plt.figure(figsize=(10,5))
# plt.hist(dump[0], bins=np.linspace(0,2000,100),alpha=0.5,label='with_ground')
# #a=plt.hist(dump[1], bins=np.linspace(400,1000,100),alpha=0.5,label='without_ground')
# plt.grid(True)
# plt.legend()

# %%
data_a=[]
for i in braunches:
    data_a.append(dump[0][i])
    
# data_c=[]
# for i in braunches:
#     data_c.append(dump[1][i])

# %%
data_b=np.vstack(data_a).T
del data_a


# data_x=np.vstack(data_c).T
# del data_c

# %%
signal_a = np.zeros(50*50)  # Pre-allocate result array

np.add.at(signal_a, data_b[:, 0].astype(int) - 1, data_b[:, 1])


# signal_x = np.zeros(10000)  # Pre-allocate result array

# np.add.at(signal_x, data_x[:, 0].astype(int) - 1, data_x[:, 1])

# %%
signal_a=np.array(signal_a).reshape(50,50)
# signal_x=np.array(signal_x).reshape(100,100)

# %%
plt.imshow(signal_a)
plt.colorbar()

# %%
a=np.unique(data_b[:,0],return_counts=True)

# %%
signal_b = np.zeros(50*50)
for i,j in zip(a[0],a[1]):
      signal_b[int(i)]=j

# %%
signal_b=signal_b.reshape(50,50)
plt.imshow(signal_b)
plt.colorbar()

# %%
result = gaussian_filter(signal_b, sigma=5)
plt.imshow(result)
plt.colorbar()

# %%
figure, axis = plt.subplots(1, 2)
axis[0].imshow(b)
axis[0].set_title("counts")

axis[1].imshow(signal)

axis[1].set_title("energy deposeted")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 figure, axis = plt.subplots(1, 2)
# ----> 2 axis[0].imshow(b)
#       3 axis[0].set_title("counts")
#       5 axis[1].imshow(signal)
#
# NameError: name 'b' is not defined

# %%
fig = plt.figure(figsize=(10,10),dpi=400)
ax = fig.add_subplot(111, projection='3d')

x_data, y_data = np.meshgrid( np.arange(b.shape[1]),
                              np.arange(b.shape[0]) )
                             
x_data = x_data.flatten()
y_data = y_data.flatten()
z_data = b.flatten()
ax.bar3d( x_data,
          y_data,
          np.zeros(len(z_data)),
          1, 1, z_data )
plt.savefig('counts.png')

# %%
map_5050 = data_b[:,0]==9999

plt.hist(data_b[map_5050,1],bins=np.linspace(0,700,50))

# %%
np.count_nonzero(map_5050)

# %%
a=np.unique(data_b[:,0],return_counts=True)

# %%
a

# %%
refl = result

fig = plt.figure(figsize=(10,10),dpi=400)
ax = fig.add_subplot(111, projection='3d')

x_data, y_data = np.meshgrid( np.arange(refl.shape[1]),
                              np.arange(refl.shape[0]) )
                             
x_data = x_data.flatten()
y_data = y_data.flatten()
z_data = refl.flatten()
ax.bar3d( x_data,
          y_data,
          np.zeros(len(z_data)),
          1, 1, z_data )
plt.savefig('myfield.png')

# %%
plt.plot(result[-1])

# %%
c = data_b[:,0]==25*25+int(25/2)

# %%
plt.figure(figsize=(10,5))
plt.hist(data_b[c,1],bins=np.linspace(1,1500,100))
plt.axvline(x = 1460-511-511, color = 'r')
plt.axvline(x = 1460-511, color = 'r')
plt.axvline(x = 1460, color = 'r')
plt.axvline(x = 511, color = 'r')
plt.grid(True)

# %%
1460-511-511
# Out:
# 438

# %%
plt.plot(signal_b[25])
plt.plot(result[25])
plt.plot(result[25]+np.sqrt(result[25]))
plt.plot(result[25]-np.sqrt(result[25]))
