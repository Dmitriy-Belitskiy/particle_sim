# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
a=np.random.uniform(low=0.0, high=1.0, size=500000)

# %%
plt.hist(a,bins=np.linspace(0,1,100))
# Out:
# (array([5013., 5001., 4943., 5004., 5010., 5082., 5054., 5137., 5071.,
#         4842., 5066., 5078., 5084., 5068., 5097., 4897., 5152., 5057.,
#         4973., 4970., 5010., 5049., 4990., 5075., 5026., 5063., 5047.,
#         5039., 4927., 5073., 4934., 5215., 5040., 5009., 5105., 5114.,
#         5096., 4980., 5125., 4967., 5084., 5007., 5225., 5069., 5076.,
#         5000., 5059., 5069., 5026., 5050., 4974., 5155., 5029., 5092.,
#         5011., 5106., 4955., 5042., 4994., 5024., 4990., 5022., 4997.,
#         5054., 5037., 5081., 5049., 5010., 5119., 5117., 5016., 4936.,
#         5013., 5073., 5187., 5231., 5119., 5078., 5067., 5211., 4993.,
#         5131., 4977., 4972., 4952., 5114., 5001., 4994., 4994., 5022.,
#         5109., 5058., 5092., 5136., 5051., 5118., 5080., 5178., 5091.]),
#  array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#         0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
# ...

# %%
def gen_dir():
    M_PI=np.pi
    rand_var_1=np.random.uniform(low=0.0, high=1.0, size=None)**0.5
    rand_var_2=np.random.uniform(low=0.0, high=1.0, size=None)
    
    
    
    theta =rand_var_1*M_PI/512
    
    
    phi =  rand_var_2* M_PI*2
    
    return(theta,phi)

a=[]

for i in range(100000):
    theta,phi=gen_dir()
    xDirection = np.sin(theta) * np.cos(phi);
    yDirection = np.cos(theta);
    zDirection = np.sin(theta) * np.sin(phi);
    
    a.append([xDirection,yDirection,zDirection])
    
a=np.array(a)

plt.figure(figsize=(10,10))
plt.scatter(a[:,0],a[:,2],alpha=0.1,s=1)
plt.grid(True)

# %%
val=np.random.uniform(low=0., high=1., size=10000)
c=val**0.5
plt.hist(c,density=True)
# Out:
# (array([0.10647338, 0.3033487 , 0.51127313, 0.72321544, 0.88593891,
#         1.14609557, 1.34397535, 1.45948893, 1.68951161, 1.8753378 ]),
#  array([0.00442585, 0.10398125, 0.20353665, 0.30309205, 0.40264744,
#         0.50220284, 0.60175824, 0.70131364, 0.80086903, 0.90042443,
#         0.99997983]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Define the starting point and components of the vector
origin = np.array([0, 0, 0])  # Vector origin point
vector = np.array([0, 0, 1])  # Vector components

# Set up the figure and 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the vector from origin to the endpoint
ax.quiver(*origin, *vector, color='b', arrow_length_ratio=0.1)

# Set axis labels and limits
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

# Display the plot
plt.show()

# %%
R_z
# Out:
# array([[ 1., -0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
R_y
# Out:
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [-0.,  0.,  1.]])

# %%
teta=np.pi/4
phi=0

R_z=np.array([[np.cos(phi),-np.sin(phi),0],
              [np.sin(phi), np.cos(phi),0],
              [0,0,1]])


R_y=np.array([[np.cos(teta),0,np.sin(teta)],
              [0, 1,0],
              [-np.sin(teta),0,np.cos(teta)]])


R=np.dot(R_z,R_y)





vector = np.array([0, 1, 0])

vector_rot=np.dot(R,vector)


# Set up the figure and 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the vector from origin to the endpoint
ax.quiver(*origin, *vector, color='b', arrow_length_ratio=0.1)

ax.quiver(*origin, *vector_rot, color='r', arrow_length_ratio=0.1)
# Set axis labels and limits
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

# Display the plot
plt.show()
