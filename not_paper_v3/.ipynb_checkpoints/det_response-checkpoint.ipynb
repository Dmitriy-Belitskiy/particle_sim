# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot
from concurrent.futures import ThreadPoolExecutor
import os
import glob
import re
from tqdm import tqdm
import imageio
#import open3d as o3d

import matplotlib.animation as animation

# %%
files=glob.glob("./build/dump/data_root/*root")

sorted_files = sorted(files, key=lambda x: int(re.search(r'\d+', x).group()))

#sorted_files = sorted(files, key=lambda x: int(re.search(r'\d+', x).group()))

# %%
print(sorted_files)
sorted_files=[sorted_files[2]]

sorted_files
# Out:
# ['./build/dump/data_root/output0_1m.root', './build/dump/data_root/output0_10m.root', './build/dump/data_root/output0_10m_v2.root', './build/dump/data_root/output0_100m.root', './build/dump/data_root/output_basic1.root', './build/dump/data_root/output3.root', './build/dump/data_root/output6.root']
# ['./build/dump/data_root/output0_10m_v2.root']

# %%
dump=[]
labels=[]


for file in sorted_files:
    labels.append(file)
    workers=8

    decompression_executor = ThreadPoolExecutor(max_workers=workers)
    interpretation_executor = ThreadPoolExecutor(max_workers=workers)


    with uproot.open(file,num_workers=workers,
                     decompression_executor=decompression_executor,
                     interpretation_executor=interpretation_executor) as file:
        print('start_loading')
        tree = file['B4;1']
        braunches=['ID','enr','leng']
        data=tree.arrays( braunches,library="np")

        # Clean up executors
    decompression_executor.shutdown()
    interpretation_executor.shutdown()

    dump.append(data)
# Out:
# start_loading

# %%
# plt.figure(figsize=(10,5))
# plt.hist(dump[0], bins=np.linspace(0,2000,100),alpha=0.5,label='with_ground')
# #a=plt.hist(dump[1], bins=np.linspace(400,1000,100),alpha=0.5,label='without_ground')
# plt.grid(True)
# plt.legend()

# %%
data_a=[]
for i in braunches:
    data_a.append(dump[0][i])

# %%
data_b=np.vstack(data_a).T
del data_a

# %%
matrix_50=data_a[:,0]==5050

plt.figure(figsize=(10,5))
plt.hist(data_a[matrix_50,2],bins=np.linspace(0,100,100))
plt.grid(True)
plt.axvline(x = 80, color = 'r')
#plt.savefig('fail.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 matrix_50=data_a[:,0]==5050
#       3 plt.figure(figsize=(10,5))
#       4 plt.hist(data_a[matrix_50,2],bins=np.linspace(0,100,100))
#
# NameError: name 'data_a' is not defined

# %%
matrix_50=data_a[:,0]==5000

plt.figure(figsize=(10,5))
plt.hist(data_a[matrix_50,1],bins=np.linspace(0,2000,30))
plt.grid(True)
plt.axvline(x = 2000, color = 'r')
#plt.savefig('fail.png')

# %%
matrix_50=data_a[:,0]==5000

# %%
np.count_nonzero(matrix_50)
# Out:
# 4908

# %%
data_a[:,-3:]
# Out:
# array([[4597.        , 2000.        ,   17.98582268],
#        [4598.        , 2000.        ,   70.84134674],
#        [4498.        , 2000.        ,   19.3330307 ],
#        ...,
#        [ 981.        , 2000.        ,  105.9182663 ],
#        [ 881.        , 2000.        ,   10.78588486],
#        [ 882.        , 2000.        ,   68.13535309]])

# %%
def save_ply(filename, points):
    """
    Save 3D points to a .ply file using Open3D.
    
    :param filename: Output filename (string)
    :param points: NumPy array of shape (N, 3) containing 3D points
    """
    # Create Open3D PointCloud object
    points=np.ascontiguousarray(points)
    
    pcd = o3d.geometry.PointCloud()
    
    # Convert NumPy array to Open3D format
    pcd.points = o3d.utility.Vector3dVector(points)
    
    # Save to PLY file
    o3d.io.write_point_cloud(filename, pcd)

# %%
save_ply('hehe_7.ply',data_a[matrix_50,-3:])

# %%
data_a[1]
# Out:
# array([  69.        ,  270.49566778,   34.28226094, -285.18743412,
#           2.35631671, 1554.04430603])

# %%
len(matrix_50)
# Out:
# 1011188

# %%
a=np.unique(data_a[:,0],return_inverse=True)

# %%
a
# Out:
# (array([0.000e+00, 1.000e+00, 2.000e+00, ..., 9.997e+03, 9.998e+03,
#         9.999e+03]),
#  array([5347, 4055, 4063, ..., 6423, 6422, 4650]))

# %%
plt.plot(a[0],a[1])

# %%
b=a[1].reshape(100,100)

# %%
plt.imshow(b)
plt.colorbar()

# %%
j=a[0]//100

# %%
i=a[0]-(a[0]//100)*100
i
# Out:
# array([ 0.,  1.,  2., ..., 97., 98., 99.])

# %%
picture = np.zeros((100,100))
for item,value in zip(a[0],a[1]):
    j=int(item//100)
    i=int(item-(item//100)*100)
    picture[i,j]=value

# %%
plt.imshow(picture)
plt.colorbar()

# %%
signal=[]
for i in tqdm(range(10000)):
    map_= data_a[:,0]==i
    signal.append(np.sum(data_a[map_,2]))
# Out:
#  12%|████████████████                                                                                                                  | 1236/10000 [00:07<00:56, 155.75it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 signal=[]
#       2 for i in tqdm(range(10000)):
# ----> 3     map_= data_a[:,0]==i
#
# KeyboardInterrupt:

# %%
signal=np.array(signal).reshape(100,100)

# %%
plt.imshow(signal)
plt.colorbar()

# %%
signal.shape
# Out:
# (100, 100)

# %%
b=np.split(data_a,a[0],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 b=np.split(data_a,a[0],axis=0)
#
# File ~/miniconda3/envs/geant310/lib/python3.10/site-packages/numpy/lib/_shape_base_impl.py:876, in split(ary, indices_or_sections, axis)
#     873     if N % sections:
#     874         raise ValueError(
#     875             'array split does not result in an equal division') from None
# --> 876 return array_split(ary, indices_or_sections, axis)
#
# File ~/miniconda3/envs/geant310/lib/python3.10/site-packages/numpy/lib/_shape_base_impl.py:792, in array_split(ary, indices_or_sections, axis)
#     790     st = div_points[i]
#     791     end = div_points[i + 1]
# --> 792     sub_arys.append(_nx.swapaxes(sary[st:end], axis, 0))
#     794 return sub_arys
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
c=a[0].astype(dtype=int)

# %%
signal = np.zeros(10000)  # Pre-allocate result array

np.add.at(signal, data_b[:, 0].astype(int) - 1, data_b[:, 2])

# %%
signal=np.array(signal).reshape(100,100)

# %%
plt.imshow(signal)
plt.colorbar()

# %%
fig = plt.figure(figsize=(10,10),dpi=400)
ax = fig.add_subplot(111, projection='3d')

x_data, y_data = np.meshgrid( np.arange(signal.shape[1]),
                              np.arange(signal.shape[0]) )
                             
x_data = x_data.flatten()
y_data = y_data.flatten()
z_data = signal.flatten()
ax.bar3d( x_data,
          y_data,
          np.zeros(len(z_data)),
          1, 1, z_data )
plt.savefig('myfield.png')
